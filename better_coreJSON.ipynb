# %% [markdown]
# # "Better" core Bundle json
# ## by rigged Coinflip
#
# ##### I found the official Riot Games JSON Files to be incomplete, so I changed them a bit and added missing keywords/metadata.
#
#
# MIT Licence, please mention me if you use this.

# %%
import json

#Keywords and Regions
'''
path_source: Where your globals-en_us.json is located - not tested for other languages (like globals-de_de.json)
path_save: The folder you want the new JSON Files saved to
'''
def core_import(path_source, path_save):
    
    with open (path_source) as f:
        core = json.load(f)
        print(f"Opened Core Bundle from {path_source}")
    
    lookup_dict = {}
    keywords_dict = {}
    for keyword in core['keywords']:
        #special case as both Overwhelm and SpellOverwhelm have "name" : "Overwhelm"
        if not keyword['nameRef'] == "SpellOverwhelm":
            keywords_dict[keyword['name']] = keyword['description']

            abbreviation = keyword['name'].replace(" ", "").replace("'", "").replace("&", "").lower()
            lookup_dict[abbreviation] = keyword['name']
            abbreviation = keyword['nameRef'].replace(" ", "").replace("'", "").replace("&", "").lower()
            lookup_dict[abbreviation] = keyword['name']
        
        #special cases:
        #same name:
        keywords_dict['SpellOverwhelm'] = "Inflicts damage beyond what would kill the target(s) to the enemy Nexus."
        lookup_dict['spelloverwhelm'] = 'SpellOverwhelm'
        
        #region abbreviations:
        lookup_dict['pnz'] = "Piltover & Zaun"
        lookup_dict['pz'] = "Piltover & Zaun"
        lookup_dict['piltoverandzaun'] = "Piltover & Zaun"
        lookup_dict['piltover'] = "Piltover & Zaun"
        lookup_dict['zaun'] = "Piltover & Zaun"
        lookup_dict['d'] = "Demacia"
        lookup_dict['de'] = "Demacia"
        lookup_dict['dem'] = "Demacia"
        lookup_dict['si'] = "Shadow Isles"
        lookup_dict['i'] = "Ionia"
        lookup_dict['io'] = "Ionia"
        lookup_dict['n'] = "Noxus"
        lookup_dict['nx'] = "Noxus"
        lookup_dict['nox'] = "Noxus"
        lookup_dict['f'] = "Freljord"
        lookup_dict['fj'] = "Freljord"
        
        #region descriptions from official Riot: https://support-legendsofruneterra.riotgames.com/hc/en-us/articles/360035541954-Regions-of-Runeterra
        keywords_dict['Demacia'] = "Justice. Honor. Duty. Proud Demacia sits on the northwestern edge of Runeterra. Once a safe haven from a brutal war, Demacia is now caught between the shifting tides of time. Can this mighty kingdom evolve to further serve its people, or do they face obsoletion along the march of progress? Stand on the side of justice!"
        keywords_dict['Freljord'] = "In the bitter cold of the frozen north, the wilderness is torn asunder from a savage, three-way civil war. Those who call this place home must find the fire within to persevere through harsh conditions and stand as paragons of fortitude and resilience. Can you weather the path to victory?"
        keywords_dict['Ionia'] = "Balance: the cornerstone of the First Lands we know as Ionia. Once, it existed aplenty, with the spiritual and physical worlds coexisting together in harmony...but such serenity is fleeting. Noxus, bent on imperial expansion, brought their insatiable hunger to Ionia's shores. Though the empire was driven out, there is an air of uncertainty hovering over the land. Are you willing to pay the price for peace?"
        keywords_dict['Noxus'] = "A brutal, expansionist empire where might makes right, Noxus sprawls across the continent in a struggle for complete dominance. However, within the region's borders beats a heart fueled by the blood, sweat, and tears of its dedicated citizens, allowing any who would try for power to step forth and seize victory...if they're able. Do you have what it takes?"
        keywords_dict['Piltover & Zaun'] = "Piltover and Zaun may seem worlds apart, but an unusual harmony connects them beyond mere proximity. On the surface, Piltover is a prosperous city of industry. Standing as Valoran's cultural center, innovation and ingenuity are prized. However, amidst the cliffs beneath Piltover lies Zaun. Swathed in a smog-induced twilight, Zaun thrives in the shadow of its sister city. When the brilliant scientists above find society too constraining, they journey below, into the toxic air to conduct their experiments. Will you choose to stay on the surface or chance what lurks beneath?"
        keywords_dict['Shadow Isles'] = "The Blessed Isles were once a thriving, fertile land...until the king of the Isles, beset by grief, sought to defy the natural order of the world, bringing ruination to the land. Now the Shadow Isles, veiled by the sinister shroud known as the Black Mist, leech life from any creature who dares step foot on those cursed shores. Do you dare turn your gaze to the Shadow Isles?"
 
        #custom keyword descriptions
        keywords_dict['Barrier'] = "Negates the next damage the unit would take. Lasts until end of round. Does not protect against overwhelm damage against the nexus."
        keywords_dict['Burst'] = "Burst spells resolve instantly. The enemy can't act before it finishes. Giving over your turn after only using burst spells makes you not pass - you can use it to wait for your enemy to do a play."
        keywords_dict['Can\'t Block'] = "This unit is unable to block."
        keywords_dict['Capture'] = "A Captured card is removed from the game. It returns when the Capturing unit leaves play. Removes all effects that were applied to it, it returns with full life."
        keywords_dict['Frostbite'] = "Set a unit's Power to 0 this round. It can be changed after. The unit can still attack."
        keywords_dict['Imbue'] = "These abilities trigger when you resolve a spell. Example: Heimerdinger, Ezreal."
        keywords_dict['Overwhelm'] = "Attacking will unpreventably redirect this unit's excess damage to the enemy nexus. Not even a barrier can stop it." #Text inspired by AeQ OutrunninKarma
        keywords_dict['SpellOverwhelm'] = "Damaging a unit will unpreventably redirect the excess damage to the enemy nexus. Not even a barrier can stop it." #Text inspired by AeQ OutrunninKarma
        keywords_dict['Trap'] = "Attaches to another card, trapping it. When the trapped card is drawn, perform the effect. For example: Teemo's Puffcaps"
        
        #Keyword descriptions of keywords that are in the game, but not in the official JSON file
        keywords_dict['Strike'] = "Deal damage to an enemy using the unit's power. Units with 0 power can't strike."
        lookup_dict['strike'] = "Strike"
        keywords_dict['Nexus Strike'] = "Effect when unit strikes the enemy Nexus."
        lookup_dict['nexusstrike'] = 'Nexus Strike'
        keywords_dict['Support'] = "Attacking with a support unit will buff the unit to its right."
        lookup_dict['support'] = "Support"
        
        #Custom Game related Data I considered important
        rarities_dict = {
            "champion" : 
            {
                "price_shards" : 3000,
                "shards_duplicate" : 750,
                "price_coins" : 300,
                "maxbuys_week" : 3,
                "duplicate_protection" : True
            },
            "epic" : 
            {
                "price_shards" : 1200,
                "shards_duplicate" : 250,
                "price_coins" : 120,
                "maxbuys_week" : 3,
                "duplicate_protection" : True
            },
            "rare" : 
            {
                "price_shards" : 300,
                "shards_duplicate" : 60,
                "price_coins" : 30,
                "maxbuys_week" : 6,
                "duplicate_protection" : False
            }, 
            "common" : {
                "price_shards" : 30,
                "shards_duplicate" : 15,
                "price_coins" : 10,
                "maxbuys_week" : 6,
                "duplicate_protection" : False
            } 
        }
        
        
        keywords_dict['Champion'] = f"Rarity. You can buy a Champion for {str(rarities_dict['champion']['price_shards'])} Shards. You can not draw duplicate Champion-Cards. If you own all Epics, you get {str(rarities_dict['champion']['shards_duplicate'])} Shards instead."
        lookup_dict['champion'] = "Champion"
        lookup_dict['championrarity'] = "Champion"
        keywords_dict['Champion Wildcard'] = f"Can be used to craft a Champion. Up to {str(rarities_dict['champion']['maxbuys_week'])} can be bought in the shop every week for {str(rarities_dict['champion']['price_coins'])} Coins each."
        lookup_dict['championwildcard'] = "Champion Wildcard"
        lookup_dict['championwc'] = "Champion Wildcard"
        keywords_dict['Epic'] = f"Rarity. You can buy an Epic for {str(rarities_dict['champion']['price_shards'])} Shards. You can not draw duplicate Epic-Cards. If you own all epics, you get {str(rarities_dict['champion']['shards_duplicate'])} Shards instead."
        lookup_dict['epic'] = "Epic"
        lookup_dict['epicrarity'] = "Epic"
        keywords_dict['Epic Wildcard'] = f"Can be used to craft an Epic. Up to {str(rarities_dict['champion']['maxbuys_week'])} can be bought in the shop every week for {str(rarities_dict['champion']['price_coins'])} Coins each."
        lookup_dict['epicwildcard'] = "Epic Wildcard"
        lookup_dict['epicwc'] = "Epic Wildcard"
        keywords_dict['Rare'] = f"Rarity. You can buy a Rare for {str(rarities_dict['champion']['price_shards'])} Shards. If you already own 3 copies of the Rare, you get {str(rarities_dict['champion']['shards_duplicate'])} Shards instead."
        lookup_dict['rare'] = "Rare"
        lookup_dict['rarerarity'] = "Rare"
        keywords_dict['Rare Wildcard'] = f"Can be used to craft a rare. Up to {str(rarities_dict['champion']['maxbuys_week'])} can be bought in the shop every week for {str(rarities_dict['champion']['price_coins'])} Coins each."
        lookup_dict['rarewildcard'] = "Rare Wildcard"
        lookup_dict['rarewc'] = "Rare Wildcard"
        keywords_dict['Common'] = f"Rarity. You can buy a common for {str(rarities_dict['champion']['price_shards'])} Shards.If you already own 3 copies of the Common, you get {str(rarities_dict['champion']['shards_duplicate'])} Shards instead."
        lookup_dict['common'] = "Common"
        lookup_dict['commonrarity'] = "Common"
        keywords_dict['Common Wildcard'] = f"Can be used to craft a common. Up to {str(rarities_dict['champion']['maxbuys_week'])} can be bought in the shop every week for {str(rarities_dict['champion']['price_coins'])} Coins each."
        lookup_dict['commonwildcard'] = "Common Wildcard"
        lookup_dict['commonwc'] = "Common Wildcard"
        
        keywords_dict['Champion Cardtype'] = f"Cardtype. You use your mana to play a champion. You can not have more than 6 Champions in your Deck."
        lookup_dict['championcardtype'] = "Champion Cardtype"
        lookup_dict['championtype'] = "Champion Cardtype"
        keywords_dict['Unit Cardtype'] = "Card Type. You use your mana to play a Unit."
        lookup_dict['unitcardtype'] = "Unit Cardtype"
        lookup_dict['unittype'] = "Unit Cardtype"
        lookup_dict['unit'] = "Unit Cardtype"
        lookup_dict['units'] = "Unit Cardtype"
        keywords_dict['Spell Cardtype'] = "Card Type. You can use Mana and Spellmana to pay for this card. Can have Slow, Fast or Burst Spellspeed."
        lookup_dict['spellcardtype'] = "Spell Cardtype"
        lookup_dict['spelltype'] = "Spell Cardtype"
        lookup_dict['spell'] = "Spell Cardtype"
        lookup_dict['spells'] = "Spell Cardtype"
        
        keywords_dict['Handsize'] = "You cannot hold more than 10 cards in hand at any time. If you would draw an 11th, it is obliterated."
        lookup_dict['handsize'] = "Handsize"
        keywords_dict['Coins'] = "Premium Currency of LoR. You can use it to buy wildcards, as well as cosmetics, such as boards and guardians."
        lookup_dict['coins'] = "Coins"
        lookup_dict['coin'] = "Coins"
        keywords_dict['Shards'] = "Normal Currency of LoR. You can use it to buy cards or pay for expedition runs."
        lookup_dict['shards'] = "Shards"
        lookup_dict['shard'] = "Shards"
        keywords_dict['Expediton'] = "You can play up to 3 paid expeditions each week. After that, you can play as many free trials as you wish. Each expedition has 2 Trials, your rewards depend on your best trial. You have to pay 300 Coins, 3000 Shards or 1 Expedition Token for each expedition you play."
        lookup_dict['expedition'] = "Expedition"
        keywords_dict['Mana'] = "You need Mana to play cards"
        lookup_dict['mana'] = "Mana"
        keywords_dict['Spell Mana'] = "Can only be used to play Spells."
        lookup_dict['spellmana'] = "Spell Mana"
        
    '''save modified Globals to new JSON Files'''
    #keywords and regions
    keywords_regions = [keywords_dict, lookup_dict]
    sub_path = r'\keywords_regions.json'
    with open(saveto + sub_path, 'w') as f:
        json.dump(keywords_regions, f, indent=4, sort_keys=True)
        print(f"Created File: {saveto + sub_path}")
        
    sub_path = r'\rarities.json'
    with open(saveto+ sub_path, 'w') as f:
        json.dump(rarities_dict, f, indent=4, sort_keys=False)
        print(f"Created File: {saveto + sub_path}")

# %%
if __name__ == "__main__":
    path_source = r'C:\yourfolderpath\core-en_us\en_us\data\globals-en_us.json' #path your core bundle is located
    saveto = r'C:\yoursavepath' #no "\" in the end
    core_import(path_source, saveto)
# Out:
# Opened Core Bundle from E:\Coinflip\Documents\Programmieren\LOR Card Bot\source\core-en_us\en_us\data\globals-en_us.json
# Created File: E:\Coinflip\Documents\Programmieren\LOR Card Bot\source\custom\keywords_regions.json
# Created File: E:\Coinflip\Documents\Programmieren\LOR Card Bot\source\custom\rarities.json
